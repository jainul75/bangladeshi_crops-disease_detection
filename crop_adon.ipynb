# %% [markdown]
# <a href="https://colab.research.google.com/github/jainul75/bangladeshi_crops-disease_detection/blob/main/crop_adon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
import glob as gb

from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
IMG_SIZE = (299, 299) # resolution
directory = "/content/drive/MyDrive/Corn"
BATCH_SIZE = 128
# train_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.2,
#                                              subset='training',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset1 = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)

# %%
import os
import shutil

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Corn'
destination_folder = '/content/drive/MyDrive/corntest'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the first specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Get the first specified percentage of files
            files_to_move = files_in_subfolder[:num_files_to_move]

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Corn'
destination_folder = '/content/drive/MyDrive/cornvalid'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Corn'
destination_folder = '/content/drive/MyDrive/corntrain'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os

# Set the path to the source folder
source_folder = '/content/drive/MyDrive/Corn'

# Function to count classes and total images
def count_classes_and_images(folder_path):
    classes = os.listdir(folder_path)
    total_classes = len(classes)
    total_images = 0

    for class_name in classes:
        class_path = os.path.join(folder_path, class_name)
        if os.path.isdir(class_path):
            images_in_class = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])
            total_images += images_in_class
            print(f"Class: {class_name}, Images: {images_in_class}")

    print(f"Total Classes: {total_classes}, Total Images: {total_images}")

# Count classes and total images in the source folder
count_classes_and_images(source_folder)
# Out:
# Class: Corn___Northern_Leaf_Blight, Images: 0
# Class: Corn___Gray_Leaf_Spot, Images: 0
# Class: Corn___Common_Rust, Images: 0
# Class: Corn___Healthy, Images: 0
# Total Classes: 4, Total Images: 0

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

IMG_SIZE = (299, 299)  # resolution
BATCH_SIZE = 128

# Define the directories for training, testing, and validation
train_directory = '/content/drive/MyDrive/corntrain'
test_directory = '/content/drive/MyDrive/corntest'
valid_directory = '/content/drive/MyDrive/cornvalid'

# Create TensorFlow datasets
train_dataset = image_dataset_from_directory(
    train_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

test_dataset = image_dataset_from_directory(
    test_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

valid_dataset = image_dataset_from_directory(
    valid_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

# Optional: You can also specify the class names if you have a specific order for your classes
class_names = train_dataset.class_names

# Print class names
print("Class Names:", class_names)
# Out:
# Found 3131 files belonging to 4 classes.
# Found 385 files belonging to 4 classes.
# Found 346 files belonging to 4 classes.
# Class Names: ['Corn___Common_Rust', 'Corn___Gray_Leaf_Spot', 'Corn___Healthy', 'Corn___Northern_Leaf_Blight']

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Corn___Common_Rust',
#  'Corn___Gray_Leaf_Spot',
#  'Corn___Healthy',
#  'Corn___Northern_Leaf_Blight']

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(train_directory):
    files = gb.glob(pathname=str(train_directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
plt.figure(figsize=(9,5))
sns.barplot(x=['Corn___Common_Rust', 'Corn___Gray_Leaf_Spot', 'Corn___Healthy', 'Corn___Northern_Leaf_Blight'], y=Data_imbalance, palette="rocket")
plt.show()

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import glob as gb

sns.set_theme(style="whitegrid")

# Assuming you already have Data_imbalance calculated
# If not, you should calculate it before using it in this code

# Print the dataset class-wise count
for folder, count in zip(['Corn___Common_Rust', 'Corn___Gray_Leaf_Spot', 'Corn___Healthy', 'Corn___Northern_Leaf_Blight'], Data_imbalance):
    print(f"Class '{folder}': {count} samples")

# Create the bar plot
plt.figure(figsize=(13,7))
sns.barplot(x=['Corn___Common_Rust', 'Corn___Gray_Leaf_Spot', 'Corn___Healthy', 'Corn___Northern_Leaf_Blight'], y=Data_imbalance, palette="rocket")
plt.show()
# Out:
# Class 'Corn___Common_Rust': 799 samples
# Class 'Corn___Gray_Leaf_Spot': 416 samples
# Class 'Corn___Healthy': 966 samples
# Class 'Corn___Northern_Leaf_Blight': 950 samples

# %%
total = 0
for i in range(0,len(Data_imbalance)) :
    total +=Data_imbalance[i]

weight_for_0 = (1 / Data_imbalance[0]) * (total / 7.0)
weight_for_1 = (1 / Data_imbalance[1]) * (total / 7.0)
weight_for_2 = (1 / Data_imbalance[2]) * (total / 7.0)
weight_for_3 = (1 / Data_imbalance[3]) * (total / 7.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
print('Weight for class 3: {:.2f}'.format(weight_for_3))
# Out:
# Weight for class 0: 0.56
# Weight for class 1: 1.08
# Weight for class 2: 0.46
# Weight for class 3: 0.47

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
augmented_count = 0

for image, _ in train_dataset:
    augmented_images = data_augmentation(image)
    augmented_count += augmented_images.shape[0]  # Count the number of augmented images

original_count = len(train_dataset) * BATCH_SIZE  # Total number of original images
total_count = original_count + augmented_count    # Total number of images after augmentation

increase_percentage = ((total_count - original_count) / original_count) * 100

print(f"Original image count: {original_count}")
print(f"Augmented image count: {augmented_count}")
print(f"Total image count after augmentation: {total_count}")
print(f"Increase in image count: {increase_percentage:.2f}%")
# Out:
# Original image count: 3200
# Augmented image count: 3131
# Total image count after augmentation: 6331
# Increase in image count: 97.84%

# %%
IMG_SHAPE = IMG_SIZE +(3,)
base_model = tf.keras.applications.InceptionV3(input_shape=IMG_SHAPE, include_top= True, weights='imagenet')

# %%
type(base_model)
preprocess_input = tf.keras.applications.inception_v3.preprocess_input

# %%
nb_layers = len(base_model.layers)
print("Numbers of Layers =" , nb_layers)
print(base_model.layers[nb_layers - 2].name)  # pre- Last name
print(base_model.layers[nb_layers - 1].name)
# Out:
# Numbers of Layers = 313
# avg_pool
# predictions

# %%
# iterate over first batch (32 image) in trainset
image_batch, label_batch = next(iter(train_dataset))  # 32 image arrays
feature_batch = base_model(image_batch)  # run the model on those 32 image (base model with its 1000 causes classification)
print(feature_batch.shape)  # 32 for number of images in this batch and 1000 for classes
# Out:
# (128, 1000)

# %%
def corn( image_shape=IMG_SIZE):
    ''' Define a tf.keras model for multi-class classification out of the InceptionV3 model '''
    image_shape = image_shape + (3,)

    inception_model = tf.keras.applications.InceptionV3(input_shape=IMG_SHAPE, include_top= False,weights='imagenet')
    inception_model.trainable = True
    for layer in inception_model.layers[0 : 291]:
        layer.trainable = False

    inputs = tf.keras.Input(image_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(inputs)
    x = inception_model(x , training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    prediction_layer = tf.keras.layers.Dense(7 ,activation = "softmax")
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)
    model.summary()
    return model

# %%
corn = corn(IMG_SIZE)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 299, 299, 3)       0
#  a)
#
#  tf.math.subtract (TFOpLamb  (None, 299, 299, 3)       0
#  da)
#
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 7)                 14343
#
# =================================================================
# Total params: 21817127 (83.23 MB)
# Trainable params: 1949703 (7.44 MB)
# Non-trainable params: 19867424 (75.79 MB)
# _________________________________________________________________

# %%
base_learning_rate = 0.001
corn.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
model_filepath="/content/drive/MyDrive/corninception-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(
    filepath = model_filepath ,
    monitor ='val_accuracy',
    mode = 'max' ,
    save_best_only =True ,
    verbose = 1
)

# %%
history = corn.fit(train_dataset, verbose = 2, epochs = 50, class_weight= class_weight,
                               validation_data = valid_dataset, use_multiprocessing = True, callbacks=[checkpoint])
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.91329, saving model to /content/drive/MyDrive/corninception-01-0.9133.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 - 52s - loss: 0.3822 - accuracy: 0.7934 - val_loss: 0.2211 - val_accuracy: 0.9133 - 52s/epoch - 2s/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.91329 to 0.95376, saving model to /content/drive/MyDrive/corninception-02-0.9538.hdf5
# 25/25 - 17s - loss: 0.0725 - accuracy: 0.9559 - val_loss: 0.1030 - val_accuracy: 0.9538 - 17s/epoch - 679ms/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.95376 to 0.96821, saving model to /content/drive/MyDrive/corninception-03-0.9682.hdf5
# 25/25 - 18s - loss: 0.0467 - accuracy: 0.9735 - val_loss: 0.0813 - val_accuracy: 0.9682 - 18s/epoch - 708ms/step
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.96821 to 0.97977, saving model to /content/drive/MyDrive/corninception-04-0.9798.hdf5
# 25/25 - 19s - loss: 0.0322 - accuracy: 0.9821 - val_loss: 0.0587 - val_accuracy: 0.9798 - 19s/epoch - 748ms/step
# Epoch 5/50
#
# Epoch 5: val_accuracy did not improve from 0.97977
# 25/25 - 18s - loss: 0.0236 - accuracy: 0.9882 - val_loss: 0.0754 - val_accuracy: 0.9740 - 18s/epoch - 704ms/step
# Epoch 6/50
#
# Epoch 6: val_accuracy did not improve from 0.97977
# 25/25 - 16s - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.0624 - val_accuracy: 0.9798 - 16s/epoch - 642ms/step
# Epoch 7/50
#
# Epoch 7: val_accuracy did not improve from 0.97977
# 25/25 - 18s - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0551 - val_accuracy: 0.9798 - 18s/epoch - 717ms/step
# Epoch 8/50
#
# Epoch 8: val_accuracy did not improve from 0.97977
# 25/25 - 17s - loss: 0.0074 - accuracy: 0.9971 - val_loss: 0.0544 - val_accuracy: 0.9769 - 17s/epoch - 677ms/step
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 0.97977
# 25/25 - 17s - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0574 - val_accuracy: 0.9798 - 17s/epoch - 681ms/step
# Epoch 10/50
#
# Epoch 10: val_accuracy improved from 0.97977 to 0.98266, saving model to /content/drive/MyDrive/corninception-10-0.9827.hdf5
# 25/25 - 19s - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.0553 - val_accuracy: 0.9827 - 19s/epoch - 760ms/step
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.0612 - val_accuracy: 0.9798 - 16s/epoch - 658ms/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0575 - val_accuracy: 0.9798 - 17s/epoch - 670ms/step
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 0.9798 - 16s/epoch - 652ms/step
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9798 - 17s/epoch - 698ms/step
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 0.9769 - 17s/epoch - 665ms/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9827 - 17s/epoch - 664ms/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 9.5436e-04 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 0.9769 - 17s/epoch - 671ms/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.98266
# 25/25 - 18s - loss: 7.9768e-04 - accuracy: 1.0000 - val_loss: 0.0588 - val_accuracy: 0.9798 - 18s/epoch - 701ms/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 5.4999e-04 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9798 - 17s/epoch - 662ms/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 5.5239e-04 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9798 - 17s/epoch - 678ms/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 4.8087e-04 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9798 - 16s/epoch - 653ms/step
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 4.9746e-04 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9798 - 16s/epoch - 657ms/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 4.1227e-04 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9798 - 16s/epoch - 651ms/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 3.7279e-04 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9798 - 16s/epoch - 654ms/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 3.5049e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9798 - 17s/epoch - 689ms/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 2.7652e-04 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9798 - 17s/epoch - 664ms/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 2.7790e-04 - accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 0.9798 - 17s/epoch - 666ms/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.98266
# 25/25 - 18s - loss: 3.6783e-04 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9798 - 18s/epoch - 713ms/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.98266
# 25/25 - 18s - loss: 3.4561e-04 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9798 - 18s/epoch - 701ms/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 3.4221e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9827 - 17s/epoch - 662ms/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.98266
# 25/25 - 18s - loss: 2.0089e-04 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9827 - 18s/epoch - 733ms/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 2.1711e-04 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 0.9798 - 17s/epoch - 662ms/step
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 2.2212e-04 - accuracy: 1.0000 - val_loss: 0.0720 - val_accuracy: 0.9798 - 17s/epoch - 666ms/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 1.8940e-04 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9798 - 17s/epoch - 692ms/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 1.7377e-04 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9798 - 16s/epoch - 653ms/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 1.8256e-04 - accuracy: 1.0000 - val_loss: 0.0724 - val_accuracy: 0.9798 - 17s/epoch - 672ms/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.98266
# 25/25 - 18s - loss: 1.7579e-04 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9798 - 18s/epoch - 719ms/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 1.5083e-04 - accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 0.9798 - 17s/epoch - 662ms/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 1.7406e-04 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9798 - 16s/epoch - 654ms/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 1.1810e-04 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9798 - 17s/epoch - 697ms/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 1.0478e-04 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9798 - 16s/epoch - 656ms/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 1.1621e-04 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9798 - 17s/epoch - 673ms/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.98266
# 25/25 - 18s - loss: 1.2323e-04 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9798 - 18s/epoch - 737ms/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 1.0545e-04 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9798 - 16s/epoch - 652ms/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 9.5364e-05 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9798 - 16s/epoch - 651ms/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.98266
# 25/25 - 18s - loss: 8.7349e-05 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 0.9798 - 18s/epoch - 724ms/step
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 1.0167e-04 - accuracy: 1.0000 - val_loss: 0.0822 - val_accuracy: 0.9798 - 17s/epoch - 660ms/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.98266
# 25/25 - 16s - loss: 1.0696e-04 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9798 - 16s/epoch - 660ms/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.98266
# 25/25 - 18s - loss: 1.0684e-04 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 0.9798 - 18s/epoch - 717ms/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.98266
# 25/25 - 17s - loss: 7.6440e-05 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9798 - 17s/epoch - 686ms/step

# %%
corn.evaluate(test_dataset , verbose = 1)
# Out:
# 4/4 [==============================] - 60s 839ms/step - loss: 0.1020 - accuracy: 0.9714
# [0.10201296955347061, 0.9714285731315613]

# %%
plt.figure(figsize=(20, 15))
for images, labels in test_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = corn.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = corn.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 6s 88ms/step
# 4/4 [==============================] - 1s 108ms/step
# 4/4 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 2s 2s/step
# ROC AUC for Corn___Common_Rust: 1.0000
# ROC AUC for Corn___Gray_Leaf_Spot: 0.9367
# ROC AUC for Corn___Healthy: 0.9939
# ROC AUC for Corn___Northern_Leaf_Blight: 0.9674
#                              precision    recall  f1-score   support
#
#          Corn___Common_Rust       1.00      1.00      1.00       119
#       Corn___Gray_Leaf_Spot       0.94      0.88      0.91        51
#              Corn___Healthy       0.99      0.99      0.99       117
# Corn___Northern_Leaf_Blight       0.93      0.96      0.94        98
#
#                    accuracy                           0.97       385
#                   macro avg       0.96      0.96      0.96       385
#                weighted avg       0.97      0.97      0.97       385

# %%
from sklearn.metrics import classification_report, confusion_matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix (Inceptionv3)')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = corn.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves
plt.figure(figsize=(10, 8))

for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f}) for {class_names[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification (Inceptionv3)')
plt.legend(loc='lower right')
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 0s 130ms/step
# 4/4 [==============================] - 0s 115ms/step
# 4/4 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 26ms/step
# ROC AUC for Corn___Common_Rust: 1.0000
# ROC AUC for Corn___Gray_Leaf_Spot: 0.9367
# ROC AUC for Corn___Healthy: 0.9939
# ROC AUC for Corn___Northern_Leaf_Blight: 0.9674
#                              precision    recall  f1-score   support
#
#          Corn___Common_Rust       1.00      1.00      1.00       119
#       Corn___Gray_Leaf_Spot       0.94      0.88      0.91        51
#              Corn___Healthy       0.99      0.99      0.99       117
# Corn___Northern_Leaf_Blight       0.93      0.96      0.94        98
#
#                    accuracy                           0.97       385
#                   macro avg       0.96      0.96      0.96       385
#                weighted avg       0.97      0.97      0.97       385
