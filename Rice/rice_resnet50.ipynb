# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
import glob as gb

from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
IMG_SIZE = (299, 299) # resolution
directory = "/content/drive/MyDrive/Rice"
BATCH_SIZE = 128
# train_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.2,
#                                              subset='training',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset1 = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)

# %%
import os
import shutil

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Rice'
destination_folder = '/content/drive/MyDrive/ricetest'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the first specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Get the first specified percentage of files
            files_to_move = files_in_subfolder[:num_files_to_move]

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Rice'
destination_folder = '/content/drive/MyDrive/ricevalid'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Rice'
destination_folder = '/content/drive/MyDrive/ricetrain'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os

# Set the path to the source folder
source_folder = '/content/drive/MyDrive/Rice'

# Function to count classes and total images
def count_classes_and_images(folder_path):
    classes = os.listdir(folder_path)
    total_classes = len(classes)
    total_images = 0

    for class_name in classes:
        class_path = os.path.join(folder_path, class_name)
        if os.path.isdir(class_path):
            images_in_class = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])
            total_images += images_in_class
            print(f"Class: {class_name}, Images: {images_in_class}")

    print(f"Total Classes: {total_classes}, Total Images: {total_images}")

# Count classes and total images in the source folder
count_classes_and_images(source_folder)
# Out:
# Class: Rice___Leaf_Blast, Images: 0
# Class: Rice___Brown_Spot, Images: 0
# Class: Rice___Neck_Blast, Images: 0
# Class: Rice___Healthy, Images: 0
# Total Classes: 4, Total Images: 0

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

IMG_SIZE = (299, 299)  # resolution
BATCH_SIZE = 128

# Define the directories for training, testing, and validation
train_directory = '/content/drive/MyDrive/ricetrain'
test_directory = '/content/drive/MyDrive/ricetest'
valid_directory = '/content/drive/MyDrive/ricevalid'

# Create TensorFlow datasets
train_dataset = image_dataset_from_directory(
    train_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

test_dataset = image_dataset_from_directory(
    test_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

valid_dataset = image_dataset_from_directory(
    valid_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

# Optional: You can also specify the class names if you have a specific order for your classes
class_names = train_dataset.class_names

# Print class names
print("Class Names:", class_names)
# Out:
# Found 3305 files belonging to 4 classes.
# Found 406 files belonging to 4 classes.
# Found 367 files belonging to 4 classes.
# Class Names: ['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast']

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Rice___Brown_Spot',
#  'Rice___Healthy',
#  'Rice___Leaf_Blast',
#  'Rice___Neck_Blast']

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(train_directory):
    files = gb.glob(pathname=str(train_directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
plt.figure(figsize=(9,5))
sns.barplot(x=['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], y=Data_imbalance, palette="rocket")
plt.show()
# Out:
# <ipython-input-12-38e8cc4b03cb>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], y=Data_imbalance, palette="rocket")

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import glob as gb

sns.set_theme(style="whitegrid")

# Assuming you already have Data_imbalance calculated
# If not, you should calculate it before using it in this code

# Print the dataset class-wise count
for folder, count in zip(['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], Data_imbalance):
    print(f"Class '{folder}': {count} samples")

# Create the bar plot
plt.figure(figsize=(13,7))
sns.barplot(x=['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], y=Data_imbalance, palette="rocket")
plt.show()
# Out:
# Class 'Rice___Brown_Spot': 792 samples
# Class 'Rice___Healthy': 497 samples
# Class 'Rice___Leaf_Blast': 810 samples
# Class 'Rice___Neck_Blast': 1206 samples
# <ipython-input-13-154fadb04a49>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], y=Data_imbalance, palette="rocket")

# %%
total = 0
for i in range(0,len(Data_imbalance)) :
    total +=Data_imbalance[i]

weight_for_0 = (1 / Data_imbalance[0]) * (total / 7.0)
weight_for_1 = (1 / Data_imbalance[1]) * (total / 7.0)
weight_for_2 = (1 / Data_imbalance[2]) * (total / 7.0)
weight_for_3 = (1 / Data_imbalance[3]) * (total / 7.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
print('Weight for class 3: {:.2f}'.format(weight_for_3))
# Out:
# Weight for class 0: 0.60
# Weight for class 1: 0.95
# Weight for class 2: 0.58
# Weight for class 3: 0.39

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
augmented_count = 0

for image, _ in train_dataset:
    augmented_images = data_augmentation(image)
    augmented_count += augmented_images.shape[0]  # Count the number of augmented images

original_count = len(train_dataset) * BATCH_SIZE  # Total number of original images
total_count = original_count + augmented_count    # Total number of images after augmentation

increase_percentage = ((total_count - original_count) / original_count) * 100

print(f"Original image count: {original_count}")
print(f"Augmented image count: {augmented_count}")
print(f"Total image count after augmentation: {total_count}")
print(f"Increase in image count: {increase_percentage:.2f}%")
# Out:
# Original image count: 3328
# Augmented image count: 3305
# Total image count after augmentation: 6633
# Increase in image count: 99.31%

# %%
IMG_SHAPE = IMG_SIZE +(3,)
base_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE, include_top= False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
type(base_model)
preprocess_input = tf.keras.applications.resnet.preprocess_input

# %%
nb_layers = len(base_model.layers)
print("Numbers of Layers =" , nb_layers)
print(base_model.layers[nb_layers - 2].name)  # pre- Last name
print(base_model.layers[nb_layers - 1].name)
# Out:
# Numbers of Layers = 175
# conv5_block3_add
# conv5_block3_out

# %%
# iterate over first batch (32 image) in trainset
image_batch, label_batch = next(iter(train_dataset))  # 32 image arrays
feature_batch = base_model(image_batch)  # run the model on those 32 image (base model with its 1000 causes classification)
print(feature_batch.shape)  # 32 for number of images in this batch and 1000 for classes
# Out:
# (128, 10, 10, 2048)

# %%
def rice(image_shape=IMG_SIZE):
    ''' Define a tf.keras model for multi-class classification out of the InceptionV3 model '''
    image_shape = image_shape + (3,)

    resnet_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE, include_top= False,weights='imagenet')
    resnet_model.trainable = True
    for layer in resnet_model.layers[0 : 291]:
        layer.trainable = False

    inputs = tf.keras.Input(image_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(inputs)
    x = resnet_model(x , training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    prediction_layer = tf.keras.layers.Dense(7 ,activation = "softmax")
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)
    model.summary()
    return model

# %%
rice_model = rice(IMG_SIZE)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  tf.__operators__.getitem (  (None, 299, 299, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 299, 299, 3)       0
#  )
#
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 7)                 14343
#
# =================================================================
# Total params: 23602055 (90.03 MB)
# Trainable params: 14343 (56.03 KB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
base_learning_rate = 0.001
rice_model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
model_filepath="/content/drive/MyDrive/riceresnet-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(
    filepath = model_filepath ,
    monitor ='val_accuracy',
    mode = 'max' ,
    save_best_only =True ,
    verbose = 1
)

# %%
history = rice_model.fit(train_dataset, verbose = 2, epochs = 50, class_weight= class_weight,
                               validation_data = valid_dataset, use_multiprocessing = True, callbacks=[checkpoint])
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.71935, saving model to /content/drive/MyDrive/riceresnet-01-0.7193.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 26/26 - 229s - loss: 0.6442 - accuracy: 0.5882 - val_loss: 0.6799 - val_accuracy: 0.7193 - 229s/epoch - 9s/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.71935 to 0.73842, saving model to /content/drive/MyDrive/riceresnet-02-0.7384.hdf5
# 26/26 - 66s - loss: 0.4113 - accuracy: 0.7365 - val_loss: 0.5786 - val_accuracy: 0.7384 - 66s/epoch - 3s/step
# Epoch 3/50
#
# Epoch 3: val_accuracy did not improve from 0.73842
# 26/26 - 67s - loss: 0.3541 - accuracy: 0.7746 - val_loss: 0.5445 - val_accuracy: 0.7384 - 67s/epoch - 3s/step
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.73842 to 0.74932, saving model to /content/drive/MyDrive/riceresnet-04-0.7493.hdf5
# 26/26 - 70s - loss: 0.3338 - accuracy: 0.7873 - val_loss: 0.5195 - val_accuracy: 0.7493 - 70s/epoch - 3s/step
# Epoch 5/50
#
# Epoch 5: val_accuracy improved from 0.74932 to 0.78747, saving model to /content/drive/MyDrive/riceresnet-05-0.7875.hdf5
# 26/26 - 68s - loss: 0.3185 - accuracy: 0.7988 - val_loss: 0.4841 - val_accuracy: 0.7875 - 68s/epoch - 3s/step
# Epoch 6/50
#
# Epoch 6: val_accuracy improved from 0.78747 to 0.80109, saving model to /content/drive/MyDrive/riceresnet-06-0.8011.hdf5
# 26/26 - 72s - loss: 0.3011 - accuracy: 0.8130 - val_loss: 0.4675 - val_accuracy: 0.8011 - 72s/epoch - 3s/step
# Epoch 7/50
#
# Epoch 7: val_accuracy did not improve from 0.80109
# 26/26 - 72s - loss: 0.2882 - accuracy: 0.8245 - val_loss: 0.4850 - val_accuracy: 0.7875 - 72s/epoch - 3s/step
# Epoch 8/50
#
# Epoch 8: val_accuracy did not improve from 0.80109
# 26/26 - 67s - loss: 0.2825 - accuracy: 0.8284 - val_loss: 0.4772 - val_accuracy: 0.7956 - 67s/epoch - 3s/step
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 0.80109
# 26/26 - 71s - loss: 0.2702 - accuracy: 0.8396 - val_loss: 0.4683 - val_accuracy: 0.7902 - 71s/epoch - 3s/step
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 0.80109
# 26/26 - 67s - loss: 0.2707 - accuracy: 0.8387 - val_loss: 0.4594 - val_accuracy: 0.7956 - 67s/epoch - 3s/step
# Epoch 11/50
#
# Epoch 11: val_accuracy improved from 0.80109 to 0.80654, saving model to /content/drive/MyDrive/riceresnet-11-0.8065.hdf5
# 26/26 - 69s - loss: 0.2621 - accuracy: 0.8445 - val_loss: 0.4477 - val_accuracy: 0.8065 - 69s/epoch - 3s/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.80654
# 26/26 - 66s - loss: 0.2555 - accuracy: 0.8460 - val_loss: 0.4397 - val_accuracy: 0.8065 - 66s/epoch - 3s/step
# Epoch 13/50
#
# Epoch 13: val_accuracy improved from 0.80654 to 0.80926, saving model to /content/drive/MyDrive/riceresnet-13-0.8093.hdf5
# 26/26 - 71s - loss: 0.2511 - accuracy: 0.8536 - val_loss: 0.4429 - val_accuracy: 0.8093 - 71s/epoch - 3s/step
# Epoch 14/50
#
# Epoch 14: val_accuracy improved from 0.80926 to 0.83106, saving model to /content/drive/MyDrive/riceresnet-14-0.8311.hdf5
# 26/26 - 66s - loss: 0.2472 - accuracy: 0.8596 - val_loss: 0.4212 - val_accuracy: 0.8311 - 66s/epoch - 3s/step
# Epoch 15/50
#
# Epoch 15: val_accuracy improved from 0.83106 to 0.83651, saving model to /content/drive/MyDrive/riceresnet-15-0.8365.hdf5
# 26/26 - 68s - loss: 0.2420 - accuracy: 0.8569 - val_loss: 0.4154 - val_accuracy: 0.8365 - 68s/epoch - 3s/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.83651
# 26/26 - 69s - loss: 0.2388 - accuracy: 0.8626 - val_loss: 0.4215 - val_accuracy: 0.8147 - 69s/epoch - 3s/step
# Epoch 17/50
#
# Epoch 17: val_accuracy improved from 0.83651 to 0.85286, saving model to /content/drive/MyDrive/riceresnet-17-0.8529.hdf5
# 26/26 - 66s - loss: 0.2342 - accuracy: 0.8644 - val_loss: 0.4070 - val_accuracy: 0.8529 - 66s/epoch - 3s/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.85286
# 26/26 - 69s - loss: 0.2381 - accuracy: 0.8675 - val_loss: 0.4272 - val_accuracy: 0.8174 - 69s/epoch - 3s/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.85286
# 26/26 - 64s - loss: 0.2293 - accuracy: 0.8696 - val_loss: 0.4340 - val_accuracy: 0.8147 - 64s/epoch - 2s/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.85286
# 26/26 - 70s - loss: 0.2323 - accuracy: 0.8623 - val_loss: 0.4157 - val_accuracy: 0.8365 - 70s/epoch - 3s/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.85286
# 26/26 - 65s - loss: 0.2271 - accuracy: 0.8657 - val_loss: 0.4093 - val_accuracy: 0.8447 - 65s/epoch - 3s/step
# Epoch 22/50
#
# Epoch 22: val_accuracy improved from 0.85286 to 0.86921, saving model to /content/drive/MyDrive/riceresnet-22-0.8692.hdf5
# 26/26 - 70s - loss: 0.2217 - accuracy: 0.8723 - val_loss: 0.3909 - val_accuracy: 0.8692 - 70s/epoch - 3s/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.86921
# 26/26 - 66s - loss: 0.2233 - accuracy: 0.8702 - val_loss: 0.4109 - val_accuracy: 0.8392 - 66s/epoch - 3s/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.86921
# 26/26 - 67s - loss: 0.2176 - accuracy: 0.8735 - val_loss: 0.4123 - val_accuracy: 0.8447 - 67s/epoch - 3s/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.86921
# 26/26 - 72s - loss: 0.2202 - accuracy: 0.8775 - val_loss: 0.4168 - val_accuracy: 0.8420 - 72s/epoch - 3s/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.86921
# 26/26 - 69s - loss: 0.2121 - accuracy: 0.8787 - val_loss: 0.4072 - val_accuracy: 0.8420 - 69s/epoch - 3s/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.86921
# 26/26 - 71s - loss: 0.2121 - accuracy: 0.8805 - val_loss: 0.4056 - val_accuracy: 0.8556 - 71s/epoch - 3s/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.86921
# 26/26 - 65s - loss: 0.2077 - accuracy: 0.8820 - val_loss: 0.4099 - val_accuracy: 0.8420 - 65s/epoch - 3s/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.86921
# 26/26 - 70s - loss: 0.2082 - accuracy: 0.8844 - val_loss: 0.4204 - val_accuracy: 0.8283 - 70s/epoch - 3s/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.86921
# 26/26 - 66s - loss: 0.2044 - accuracy: 0.8862 - val_loss: 0.4065 - val_accuracy: 0.8447 - 66s/epoch - 3s/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.86921
# 26/26 - 70s - loss: 0.2111 - accuracy: 0.8756 - val_loss: 0.3880 - val_accuracy: 0.8692 - 70s/epoch - 3s/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 0.86921
# 26/26 - 66s - loss: 0.2013 - accuracy: 0.8871 - val_loss: 0.3873 - val_accuracy: 0.8638 - 66s/epoch - 3s/step
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.86921
# 26/26 - 68s - loss: 0.2013 - accuracy: 0.8835 - val_loss: 0.4083 - val_accuracy: 0.8447 - 68s/epoch - 3s/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.86921
# 26/26 - 73s - loss: 0.2039 - accuracy: 0.8808 - val_loss: 0.3823 - val_accuracy: 0.8638 - 73s/epoch - 3s/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.86921
# 26/26 - 66s - loss: 0.2047 - accuracy: 0.8787 - val_loss: 0.4132 - val_accuracy: 0.8392 - 66s/epoch - 3s/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.86921
# 26/26 - 70s - loss: 0.1976 - accuracy: 0.8874 - val_loss: 0.3881 - val_accuracy: 0.8556 - 70s/epoch - 3s/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.86921
# 26/26 - 66s - loss: 0.1975 - accuracy: 0.8896 - val_loss: 0.4030 - val_accuracy: 0.8501 - 66s/epoch - 3s/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.86921
# 26/26 - 70s - loss: 0.1972 - accuracy: 0.8884 - val_loss: 0.3759 - val_accuracy: 0.8665 - 70s/epoch - 3s/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.86921
# 26/26 - 66s - loss: 0.1967 - accuracy: 0.8880 - val_loss: 0.3794 - val_accuracy: 0.8583 - 66s/epoch - 3s/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.86921
# 26/26 - 71s - loss: 0.1973 - accuracy: 0.8929 - val_loss: 0.3891 - val_accuracy: 0.8474 - 71s/epoch - 3s/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.86921
# 26/26 - 66s - loss: 0.1942 - accuracy: 0.8893 - val_loss: 0.3754 - val_accuracy: 0.8665 - 66s/epoch - 3s/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.86921
# 26/26 - 68s - loss: 0.1908 - accuracy: 0.8950 - val_loss: 0.3927 - val_accuracy: 0.8556 - 68s/epoch - 3s/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.86921
# 26/26 - 65s - loss: 0.1935 - accuracy: 0.8890 - val_loss: 0.3797 - val_accuracy: 0.8583 - 65s/epoch - 2s/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.86921
# 26/26 - 66s - loss: 0.1894 - accuracy: 0.8917 - val_loss: 0.3786 - val_accuracy: 0.8610 - 66s/epoch - 3s/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.86921
# 26/26 - 70s - loss: 0.1894 - accuracy: 0.8923 - val_loss: 0.3723 - val_accuracy: 0.8665 - 70s/epoch - 3s/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.86921
# 26/26 - 65s - loss: 0.1867 - accuracy: 0.8941 - val_loss: 0.3773 - val_accuracy: 0.8638 - 65s/epoch - 2s/step
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.86921
# 26/26 - 68s - loss: 0.1888 - accuracy: 0.8911 - val_loss: 0.3763 - val_accuracy: 0.8638 - 68s/epoch - 3s/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.86921
# 26/26 - 65s - loss: 0.1847 - accuracy: 0.8929 - val_loss: 0.3784 - val_accuracy: 0.8692 - 65s/epoch - 2s/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.86921
# 26/26 - 66s - loss: 0.1860 - accuracy: 0.8953 - val_loss: 0.3868 - val_accuracy: 0.8556 - 66s/epoch - 3s/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.86921
# 26/26 - 70s - loss: 0.1792 - accuracy: 0.8962 - val_loss: 0.3681 - val_accuracy: 0.8610 - 70s/epoch - 3s/step

# %%
rice_model.evaluate(test_dataset, verbose = 1)
# Out:
# 4/4 [==============================] - 166s 1s/step - loss: 0.3870 - accuracy: 0.8621
# [0.38702309131622314, 0.8620689511299133]

# %%
plt.figure(figsize=(20, 15))
for images, labels in test_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = rice_model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = rice_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 5s 120ms/step
# 4/4 [==============================] - 1s 162ms/step
# 4/4 [==============================] - 1s 163ms/step
# 1/1 [==============================] - 1s 1s/step
# ROC AUC for Rice___Brown_Spot: 0.8568
# ROC AUC for Rice___Healthy: 0.9038
# ROC AUC for Rice___Leaf_Blast: 0.8314
# ROC AUC for Rice___Neck_Blast: 1.0000
#                    precision    recall  f1-score   support
#
# Rice___Brown_Spot       0.77      0.75      0.76        61
#    Rice___Healthy       0.83      0.91      0.87       148
# Rice___Leaf_Blast       0.82      0.71      0.76        97
# Rice___Neck_Blast       1.00      1.00      1.00       100
#
#          accuracy                           0.86       406
#         macro avg       0.86      0.84      0.85       406
#      weighted avg       0.86      0.86      0.86       406

# %%
from sklearn.metrics import classification_report, confusion_matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = rice_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves
plt.figure(figsize=(10, 8))

for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f}) for {class_names[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Crop Diseases Classification')
plt.legend(loc='lower right')
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 159ms/step
# 4/4 [==============================] - 1s 171ms/step
# 1/1 [==============================] - 0s 115ms/step
# ROC AUC for Rice___Brown_Spot: 0.8568
# ROC AUC for Rice___Healthy: 0.9038
# ROC AUC for Rice___Leaf_Blast: 0.8314
# ROC AUC for Rice___Neck_Blast: 1.0000
#                    precision    recall  f1-score   support
#
# Rice___Brown_Spot       0.77      0.75      0.76        61
#    Rice___Healthy       0.83      0.91      0.87       148
# Rice___Leaf_Blast       0.82      0.71      0.76        97
# Rice___Neck_Blast       1.00      1.00      1.00       100
#
#          accuracy                           0.86       406
#         macro avg       0.86      0.84      0.85       406
#      weighted avg       0.86      0.86      0.86       406
