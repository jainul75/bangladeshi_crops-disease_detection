# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
import glob as gb

from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
IMG_SIZE = (299, 299) # resolution
directory = "/content/drive/MyDrive/Rice"
BATCH_SIZE = 128
# train_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.2,
#                                              subset='training',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset1 = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)

# %%
import os
import shutil

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Rice'
destination_folder = '/content/drive/MyDrive/ricetest'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the first specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Get the first specified percentage of files
            files_to_move = files_in_subfolder[:num_files_to_move]

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Rice'
destination_folder = '/content/drive/MyDrive/ricevalid'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Rice'
destination_folder = '/content/drive/MyDrive/ricetrain'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os

# Set the path to the source folder
source_folder = '/content/drive/MyDrive/Rice'

# Function to count classes and total images
def count_classes_and_images(folder_path):
    classes = os.listdir(folder_path)
    total_classes = len(classes)
    total_images = 0

    for class_name in classes:
        class_path = os.path.join(folder_path, class_name)
        if os.path.isdir(class_path):
            images_in_class = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])
            total_images += images_in_class
            print(f"Class: {class_name}, Images: {images_in_class}")

    print(f"Total Classes: {total_classes}, Total Images: {total_images}")

# Count classes and total images in the source folder
count_classes_and_images(source_folder)
# Out:
# Class: Rice___Leaf_Blast, Images: 0
# Class: Rice___Brown_Spot, Images: 0
# Class: Rice___Neck_Blast, Images: 0
# Class: Rice___Healthy, Images: 0
# Total Classes: 4, Total Images: 0

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

IMG_SIZE = (299, 299)  # resolution
BATCH_SIZE = 128

# Define the directories for training, testing, and validation
train_directory = '/content/drive/MyDrive/ricetrain'
test_directory = '/content/drive/MyDrive/ricetest'
valid_directory = '/content/drive/MyDrive/ricevalid'

# Create TensorFlow datasets
train_dataset = image_dataset_from_directory(
    train_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

test_dataset = image_dataset_from_directory(
    test_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

valid_dataset = image_dataset_from_directory(
    valid_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

# Optional: You can also specify the class names if you have a specific order for your classes
class_names = train_dataset.class_names

# Print class names
print("Class Names:", class_names)
# Out:
# Found 3305 files belonging to 4 classes.
# Found 406 files belonging to 4 classes.
# Found 367 files belonging to 4 classes.
# Class Names: ['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast']

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Rice___Brown_Spot',
#  'Rice___Healthy',
#  'Rice___Leaf_Blast',
#  'Rice___Neck_Blast']

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(train_directory):
    files = gb.glob(pathname=str(train_directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
plt.figure(figsize=(9,5))
sns.barplot(x=['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], y=Data_imbalance, palette="rocket")
plt.show()
# Out:
# <ipython-input-13-38e8cc4b03cb>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], y=Data_imbalance, palette="rocket")

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import glob as gb

sns.set_theme(style="whitegrid")

# Assuming you already have Data_imbalance calculated
# If not, you should calculate it before using it in this code

# Print the dataset class-wise count
for folder, count in zip(['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], Data_imbalance):
    print(f"Class '{folder}': {count} samples")

# Create the bar plot
plt.figure(figsize=(13,7))
sns.barplot(x=['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], y=Data_imbalance, palette="rocket")
plt.show()
# Out:
# Class 'Rice___Brown_Spot': 792 samples
# Class 'Rice___Healthy': 497 samples
# Class 'Rice___Leaf_Blast': 810 samples
# Class 'Rice___Neck_Blast': 1206 samples
# <ipython-input-14-154fadb04a49>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast'], y=Data_imbalance, palette="rocket")

# %%
total = 0
for i in range(0,len(Data_imbalance)) :
    total +=Data_imbalance[i]

weight_for_0 = (1 / Data_imbalance[0]) * (total / 7.0)
weight_for_1 = (1 / Data_imbalance[1]) * (total / 7.0)
weight_for_2 = (1 / Data_imbalance[2]) * (total / 7.0)
weight_for_3 = (1 / Data_imbalance[3]) * (total / 7.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
print('Weight for class 3: {:.2f}'.format(weight_for_3))
# Out:
# Weight for class 0: 0.60
# Weight for class 1: 0.95
# Weight for class 2: 0.58
# Weight for class 3: 0.39

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
augmented_count = 0

for image, _ in train_dataset:
    augmented_images = data_augmentation(image)
    augmented_count += augmented_images.shape[0]  # Count the number of augmented images

original_count = len(train_dataset) * BATCH_SIZE  # Total number of original images
total_count = original_count + augmented_count    # Total number of images after augmentation

increase_percentage = ((total_count - original_count) / original_count) * 100

print(f"Original image count: {original_count}")
print(f"Augmented image count: {augmented_count}")
print(f"Total image count after augmentation: {total_count}")
print(f"Increase in image count: {increase_percentage:.2f}%")
# Out:
# Original image count: 3328
# Augmented image count: 3305
# Total image count after augmentation: 6633
# Increase in image count: 99.31%

# %%
IMG_SHAPE = IMG_SIZE +(3,)
base_model = tf.keras.applications.DenseNet121(input_shape=IMG_SHAPE, include_top= False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
type(base_model)
preprocess_input = tf.keras.applications.densenet.preprocess_input

# %%
nb_layers = len(base_model.layers)
print("Numbers of Layers =" , nb_layers)
print(base_model.layers[nb_layers - 2].name)  # pre- Last name
print(base_model.layers[nb_layers - 1].name)
# Out:
# Numbers of Layers = 427
# bn
# relu

# %%
# iterate over first batch (32 image) in trainset
image_batch, label_batch = next(iter(train_dataset))  # 32 image arrays
feature_batch = base_model(image_batch)  # run the model on those 32 image (base model with its 1000 causes classification)
print(feature_batch.shape)  # 32 for number of images in this batch and 1000 for classes
# Out:
# (128, 9, 9, 1024)

# %%
def rice(image_shape=IMG_SIZE):
    ''' Define a tf.keras model for multi-class classification out of the InceptionV3 model '''
    image_shape = image_shape + (3,)

    densenet_model = tf.keras.applications.DenseNet121(input_shape=IMG_SHAPE, include_top= False,weights='imagenet')
    densenet_model.trainable = True
    for layer in densenet_model.layers[0 : 291]:
        layer.trainable = False

    inputs = tf.keras.Input(image_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(inputs)
    x = densenet_model(x , training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    prediction_layer = tf.keras.layers.Dense(7 ,activation = "softmax")
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)
    model.summary()
    return model

# %%
rice_model = rice(IMG_SIZE)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 299, 299, 3)       0
#  a)
#
#  tf.nn.bias_add (TFOpLambda  (None, 299, 299, 3)       0
#  )
#
#  tf.math.truediv_1 (TFOpLam  (None, 299, 299, 3)       0
#  bda)
#
#  densenet121 (Functional)    (None, 9, 9, 1024)        7037504
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 7)                 7175
#
# =================================================================
# Total params: 7044679 (26.87 MB)
# Trainable params: 3058759 (11.67 MB)
# Non-trainable params: 3985920 (15.21 MB)
# _________________________________________________________________

# %%
base_learning_rate = 0.001
rice_model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
model_filepath="/content/drive/MyDrive/ricedensenet-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(
    filepath = model_filepath ,
    monitor ='val_accuracy',
    mode = 'max' ,
    save_best_only =True ,
    verbose = 1
)

# %%
history = rice_model.fit(train_dataset, verbose = 2, epochs = 50, class_weight= class_weight,
                               validation_data = valid_dataset, use_multiprocessing = True, callbacks=[checkpoint])
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.81199, saving model to /content/drive/MyDrive/ricedensenet-01-0.8120.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 26/26 - 301s - loss: 0.6647 - accuracy: 0.6006 - val_loss: 0.4883 - val_accuracy: 0.8120 - 301s/epoch - 12s/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.81199 to 0.86376, saving model to /content/drive/MyDrive/ricedensenet-02-0.8638.hdf5
# 26/26 - 75s - loss: 0.3064 - accuracy: 0.8194 - val_loss: 0.3512 - val_accuracy: 0.8638 - 75s/epoch - 3s/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.86376 to 0.89373, saving model to /content/drive/MyDrive/ricedensenet-03-0.8937.hdf5
# 26/26 - 70s - loss: 0.2149 - accuracy: 0.8802 - val_loss: 0.3108 - val_accuracy: 0.8937 - 70s/epoch - 3s/step
# Epoch 4/50
#
# Epoch 4: val_accuracy did not improve from 0.89373
# 26/26 - 72s - loss: 0.1929 - accuracy: 0.9008 - val_loss: 0.2846 - val_accuracy: 0.8883 - 72s/epoch - 3s/step
# Epoch 5/50
#
# Epoch 5: val_accuracy improved from 0.89373 to 0.89918, saving model to /content/drive/MyDrive/ricedensenet-05-0.8992.hdf5
# 26/26 - 68s - loss: 0.1635 - accuracy: 0.9150 - val_loss: 0.2948 - val_accuracy: 0.8992 - 68s/epoch - 3s/step
# Epoch 6/50
#
# Epoch 6: val_accuracy did not improve from 0.89918
# 26/26 - 71s - loss: 0.1461 - accuracy: 0.9247 - val_loss: 0.3261 - val_accuracy: 0.8965 - 71s/epoch - 3s/step
# Epoch 7/50
#
# Epoch 7: val_accuracy did not improve from 0.89918
# 26/26 - 68s - loss: 0.1307 - accuracy: 0.9322 - val_loss: 0.3501 - val_accuracy: 0.8992 - 68s/epoch - 3s/step
# Epoch 8/50
#
# Epoch 8: val_accuracy improved from 0.89918 to 0.91553, saving model to /content/drive/MyDrive/ricedensenet-08-0.9155.hdf5
# 26/26 - 76s - loss: 0.1179 - accuracy: 0.9392 - val_loss: 0.2991 - val_accuracy: 0.9155 - 76s/epoch - 3s/step
# Epoch 9/50
#
# Epoch 9: val_accuracy improved from 0.91553 to 0.92098, saving model to /content/drive/MyDrive/ricedensenet-09-0.9210.hdf5
# 26/26 - 69s - loss: 0.0975 - accuracy: 0.9540 - val_loss: 0.3422 - val_accuracy: 0.9210 - 69s/epoch - 3s/step
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 0.92098
# 26/26 - 71s - loss: 0.0848 - accuracy: 0.9601 - val_loss: 0.4490 - val_accuracy: 0.9210 - 71s/epoch - 3s/step
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.92098
# 26/26 - 67s - loss: 0.1241 - accuracy: 0.9389 - val_loss: 0.2930 - val_accuracy: 0.9155 - 67s/epoch - 3s/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.92098
# 26/26 - 71s - loss: 0.0820 - accuracy: 0.9598 - val_loss: 0.2593 - val_accuracy: 0.9046 - 71s/epoch - 3s/step
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 0.92098
# 26/26 - 67s - loss: 0.0722 - accuracy: 0.9652 - val_loss: 0.3529 - val_accuracy: 0.9101 - 67s/epoch - 3s/step
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 0.92098
# 26/26 - 71s - loss: 0.0769 - accuracy: 0.9661 - val_loss: 0.3635 - val_accuracy: 0.9155 - 71s/epoch - 3s/step
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.92098
# 26/26 - 74s - loss: 0.0550 - accuracy: 0.9752 - val_loss: 0.3774 - val_accuracy: 0.9128 - 74s/epoch - 3s/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.92098
# 26/26 - 71s - loss: 0.0630 - accuracy: 0.9707 - val_loss: 0.3828 - val_accuracy: 0.9101 - 71s/epoch - 3s/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.92098
# 26/26 - 73s - loss: 0.0535 - accuracy: 0.9752 - val_loss: 0.2687 - val_accuracy: 0.9210 - 73s/epoch - 3s/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.92098
# 26/26 - 71s - loss: 0.0454 - accuracy: 0.9779 - val_loss: 0.3860 - val_accuracy: 0.9101 - 71s/epoch - 3s/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.92098
# 26/26 - 71s - loss: 0.0421 - accuracy: 0.9779 - val_loss: 0.4185 - val_accuracy: 0.9046 - 71s/epoch - 3s/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.92098
# 26/26 - 69s - loss: 0.0527 - accuracy: 0.9752 - val_loss: 0.3382 - val_accuracy: 0.9155 - 69s/epoch - 3s/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.92098
# 26/26 - 71s - loss: 0.0448 - accuracy: 0.9788 - val_loss: 0.4750 - val_accuracy: 0.9046 - 71s/epoch - 3s/step
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.92098
# 26/26 - 67s - loss: 0.0687 - accuracy: 0.9691 - val_loss: 0.3845 - val_accuracy: 0.8883 - 67s/epoch - 3s/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.92098
# 26/26 - 71s - loss: 0.0426 - accuracy: 0.9791 - val_loss: 0.4055 - val_accuracy: 0.9019 - 71s/epoch - 3s/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.92098
# 26/26 - 67s - loss: 0.0357 - accuracy: 0.9843 - val_loss: 0.4581 - val_accuracy: 0.9019 - 67s/epoch - 3s/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.92098
# 26/26 - 69s - loss: 0.0288 - accuracy: 0.9855 - val_loss: 0.3781 - val_accuracy: 0.9046 - 69s/epoch - 3s/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.92098
# 26/26 - 72s - loss: 0.0296 - accuracy: 0.9864 - val_loss: 0.4281 - val_accuracy: 0.9101 - 72s/epoch - 3s/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.92098
# 26/26 - 68s - loss: 0.0235 - accuracy: 0.9888 - val_loss: 0.4734 - val_accuracy: 0.9128 - 68s/epoch - 3s/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.92098
# 26/26 - 70s - loss: 0.0207 - accuracy: 0.9903 - val_loss: 0.6847 - val_accuracy: 0.9019 - 70s/epoch - 3s/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.92098
# 26/26 - 66s - loss: 0.0299 - accuracy: 0.9852 - val_loss: 0.4284 - val_accuracy: 0.9128 - 66s/epoch - 3s/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.92098
# 26/26 - 71s - loss: 0.0245 - accuracy: 0.9873 - val_loss: 0.4971 - val_accuracy: 0.9183 - 71s/epoch - 3s/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.92098
# 26/26 - 74s - loss: 0.0272 - accuracy: 0.9882 - val_loss: 0.4995 - val_accuracy: 0.9128 - 74s/epoch - 3s/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 0.92098
# 26/26 - 70s - loss: 0.0138 - accuracy: 0.9921 - val_loss: 0.4275 - val_accuracy: 0.9183 - 70s/epoch - 3s/step
# Epoch 33/50
#
# Epoch 33: val_accuracy improved from 0.92098 to 0.92643, saving model to /content/drive/MyDrive/ricedensenet-33-0.9264.hdf5
# 26/26 - 73s - loss: 0.0105 - accuracy: 0.9939 - val_loss: 0.5820 - val_accuracy: 0.9264 - 73s/epoch - 3s/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.92643
# 26/26 - 68s - loss: 0.0042 - accuracy: 0.9976 - val_loss: 0.7157 - val_accuracy: 0.9210 - 68s/epoch - 3s/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.92643
# 26/26 - 71s - loss: 0.0226 - accuracy: 0.9930 - val_loss: 0.5959 - val_accuracy: 0.8937 - 71s/epoch - 3s/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.92643
# 26/26 - 67s - loss: 0.0606 - accuracy: 0.9728 - val_loss: 0.6532 - val_accuracy: 0.8856 - 67s/epoch - 3s/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.92643
# 26/26 - 71s - loss: 0.0354 - accuracy: 0.9812 - val_loss: 0.5087 - val_accuracy: 0.9155 - 71s/epoch - 3s/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.92643
# 26/26 - 67s - loss: 0.0244 - accuracy: 0.9891 - val_loss: 0.6073 - val_accuracy: 0.9155 - 67s/epoch - 3s/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.92643
# 26/26 - 69s - loss: 0.0231 - accuracy: 0.9891 - val_loss: 0.5905 - val_accuracy: 0.9210 - 69s/epoch - 3s/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.92643
# 26/26 - 73s - loss: 0.0200 - accuracy: 0.9906 - val_loss: 0.5780 - val_accuracy: 0.9074 - 73s/epoch - 3s/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.92643
# 26/26 - 69s - loss: 0.0106 - accuracy: 0.9943 - val_loss: 0.4763 - val_accuracy: 0.9210 - 69s/epoch - 3s/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.92643
# 26/26 - 72s - loss: 0.0039 - accuracy: 0.9967 - val_loss: 0.5377 - val_accuracy: 0.9210 - 72s/epoch - 3s/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.92643
# 26/26 - 69s - loss: 0.0029 - accuracy: 0.9973 - val_loss: 0.5027 - val_accuracy: 0.9237 - 69s/epoch - 3s/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.92643
# 26/26 - 72s - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.7156 - val_accuracy: 0.9183 - 72s/epoch - 3s/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.92643
# 26/26 - 67s - loss: 5.3373e-04 - accuracy: 0.9997 - val_loss: 0.7229 - val_accuracy: 0.9183 - 67s/epoch - 3s/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.92643
# 26/26 - 69s - loss: 5.8372e-04 - accuracy: 0.9997 - val_loss: 0.9247 - val_accuracy: 0.9237 - 69s/epoch - 3s/step
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.92643
# 26/26 - 72s - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.8554 - val_accuracy: 0.9183 - 72s/epoch - 3s/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.92643
# 26/26 - 67s - loss: 3.2259e-04 - accuracy: 1.0000 - val_loss: 0.9513 - val_accuracy: 0.9155 - 67s/epoch - 3s/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.92643
# 26/26 - 72s - loss: 2.1877e-04 - accuracy: 1.0000 - val_loss: 1.1037 - val_accuracy: 0.9183 - 72s/epoch - 3s/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.92643
# 26/26 - 74s - loss: 0.0468 - accuracy: 0.9818 - val_loss: 0.7087 - val_accuracy: 0.8828 - 74s/epoch - 3s/step

# %%
rice_model.evaluate(test_dataset, verbose = 1)
# Out:
# 4/4 [==============================] - 168s 2s/step - loss: 0.5710 - accuracy: 0.9113
# [0.5710386633872986, 0.9113300442695618]

# %%
plt.figure(figsize=(20, 15))
for images, labels in test_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = rice_model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = rice_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 9s 119ms/step
# 4/4 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 149ms/step
# 1/1 [==============================] - 2s 2s/step
# ROC AUC for Rice___Brown_Spot: 0.9035
# ROC AUC for Rice___Healthy: 0.9319
# ROC AUC for Rice___Leaf_Blast: 0.9158
# ROC AUC for Rice___Neck_Blast: 1.0000
#                    precision    recall  f1-score   support
#
# Rice___Brown_Spot       0.84      0.84      0.84        61
#    Rice___Healthy       0.94      0.90      0.92       148
# Rice___Leaf_Blast       0.83      0.89      0.86        97
# Rice___Neck_Blast       1.00      1.00      1.00       100
#
#          accuracy                           0.91       406
#         macro avg       0.90      0.91      0.90       406
#      weighted avg       0.91      0.91      0.91       406

# %%
from sklearn.metrics import classification_report, confusion_matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix (Inceptionv3)')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = rice_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves
plt.figure(figsize=(10, 8))

for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f}) for {class_names[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification (Inceptionv3)')
plt.legend(loc='lower right')
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 1s 149ms/step
# 4/4 [==============================] - 1s 151ms/step
# 1/1 [==============================] - 0s 69ms/step
# ROC AUC for Rice___Brown_Spot: 0.9035
# ROC AUC for Rice___Healthy: 0.9319
# ROC AUC for Rice___Leaf_Blast: 0.9158
# ROC AUC for Rice___Neck_Blast: 1.0000
#                    precision    recall  f1-score   support
#
# Rice___Brown_Spot       0.84      0.84      0.84        61
#    Rice___Healthy       0.94      0.90      0.92       148
# Rice___Leaf_Blast       0.83      0.89      0.86        97
# Rice___Neck_Blast       1.00      1.00      1.00       100
#
#          accuracy                           0.91       406
#         macro avg       0.90      0.91      0.90       406
#      weighted avg       0.91      0.91      0.91       406
