# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
import glob as gb

from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
IMG_SIZE = (299, 299) # resolution
directory = "/content/drive/MyDrive/Wheat"
BATCH_SIZE = 128
# train_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.2,
#                                              subset='training',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset1 = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)

# %%
import os
import shutil

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Wheat'
destination_folder = '/content/drive/MyDrive/wheattest'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the first specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Get the first specified percentage of files
            files_to_move = files_in_subfolder[:num_files_to_move]

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Wheat'
destination_folder = '/content/drive/MyDrive/wheatvalid'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Wheat'
destination_folder = '/content/drive/MyDrive/wheattrain'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os

# Set the path to the source folder
source_folder = '/content/drive/MyDrive/Wheat'

# Function to count classes and total images
def count_classes_and_images(folder_path):
    classes = os.listdir(folder_path)
    total_classes = len(classes)
    total_images = 0

    for class_name in classes:
        class_path = os.path.join(folder_path, class_name)
        if os.path.isdir(class_path):
            images_in_class = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])
            total_images += images_in_class
            print(f"Class: {class_name}, Images: {images_in_class}")

    print(f"Total Classes: {total_classes}, Total Images: {total_images}")

# Count classes and total images in the source folder
count_classes_and_images(source_folder)
# Out:
# Class: Wheat___Yellow_Rust, Images: 0
# Class: Wheat___Healthy, Images: 0
# Class: Wheat___Brown_Rust, Images: 0
# Total Classes: 3, Total Images: 0

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

IMG_SIZE = (299, 299)  # resolution
BATCH_SIZE = 128

# Define the directories for training, testing, and validation
train_directory = '/content/drive/MyDrive/wheattrain'
test_directory = '/content/drive/MyDrive/wheattest'
valid_directory = '/content/drive/MyDrive/wheatvalid'

# Create TensorFlow datasets
train_dataset = image_dataset_from_directory(
    train_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

test_dataset = image_dataset_from_directory(
    test_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

valid_dataset = image_dataset_from_directory(
    valid_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

# Optional: You can also specify the class names if you have a specific order for your classes
class_names = train_dataset.class_names

# Print class names
print("Class Names:", class_names)
# Out:
# Found 2385 files belonging to 3 classes.
# Found 293 files belonging to 3 classes.
# Found 264 files belonging to 3 classes.
# Class Names: ['Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust']

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust']

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(train_directory):
    files = gb.glob(pathname=str(train_directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
plt.figure(figsize=(9,5))
sns.barplot(x=['Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust'], y=Data_imbalance, palette="crest")
plt.show()
# Out:
# <ipython-input-10-fb326be70a4d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust'], y=Data_imbalance, palette="crest")

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import glob as gb

sns.set_theme(style="whitegrid")

# Assuming you already have Data_imbalance calculated
# If not, you should calculate it before using it in this code

# Print the dataset class-wise count
for folder, count in zip(['Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust'], Data_imbalance):
    print(f"Class '{folder}': {count} samples")

# Create the bar plot
plt.figure(figsize=(13,7))
sns.barplot(x=['Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust'], y=Data_imbalance, palette="rocket")
plt.show()
# Out:
# Class 'Wheat___Brown_Rust': 749 samples
# Class 'Wheat___Healthy': 905 samples
# Class 'Wheat___Yellow_Rust': 731 samples
# <ipython-input-11-c4c1a023e2f4>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust'], y=Data_imbalance, palette="rocket")

# %%
total = 0
for i in range(0,len(Data_imbalance)) :
    total +=Data_imbalance[i]

weight_for_0 = (1 / Data_imbalance[0]) * (total / 7.0)
weight_for_1 = (1 / Data_imbalance[1]) * (total / 7.0)
weight_for_2 = (1 / Data_imbalance[2]) * (total / 7.0)
# weight_for_3 = (1 / Data_imbalance[3]) * (total / 7.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2}    # , 3: weight_for_3

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
# print('Weight for class 3: {:.2f}'.format(weight_for_3))
# Out:
# Weight for class 0: 0.45
# Weight for class 1: 0.38
# Weight for class 2: 0.47

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
augmented_count = 0

for image, _ in train_dataset:
    augmented_images = data_augmentation(image)
    augmented_count += augmented_images.shape[0]  # Count the number of augmented images

original_count = len(train_dataset) * BATCH_SIZE  # Total number of original images
total_count = original_count + augmented_count    # Total number of images after augmentation

increase_percentage = ((total_count - original_count) / original_count) * 100

print(f"Original image count: {original_count}")
print(f"Augmented image count: {augmented_count}")
print(f"Total image count after augmentation: {total_count}")
print(f"Increase in image count: {increase_percentage:.2f}%")
# Out:
# Original image count: 2432
# Augmented image count: 2385
# Total image count after augmentation: 4817
# Increase in image count: 98.07%

# %%
IMG_SHAPE = IMG_SIZE +(3,)
base_model = tf.keras.applications.DenseNet121(input_shape=IMG_SHAPE, include_top= False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
type(base_model)
preprocess_input = tf.keras.applications.densenet.preprocess_input

# %%
nb_layers = len(base_model.layers)
print("Numbers of Layers =" , nb_layers)
print(base_model.layers[nb_layers - 2].name)  # pre- Last name
print(base_model.layers[nb_layers - 1].name)
# Out:
# Numbers of Layers = 427
# bn
# relu

# %%
# iterate over first batch (32 image) in trainset
image_batch, label_batch = next(iter(train_dataset))  # 32 image arrays
feature_batch = base_model(image_batch)  # run the model on those 32 image (base model with its 1000 causes classification)
print(feature_batch.shape)  # 32 for number of images in this batch and 1000 for classes
# Out:
# (128, 9, 9, 1024)

# %%
def wheat(image_shape=IMG_SIZE):
    ''' Define a tf.keras model for multi-class classification out of the InceptionV3 model '''
    image_shape = image_shape + (3,)

    densenet_model = tf.keras.applications.DenseNet121(input_shape=IMG_SHAPE, include_top= False,weights='imagenet')
    densenet_model.trainable = True
    for layer in densenet_model.layers[0 : 291]:
        layer.trainable = False

    inputs = tf.keras.Input(image_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(inputs)
    x = densenet_model(x , training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    prediction_layer = tf.keras.layers.Dense(7 ,activation = "softmax")
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)
    model.summary()
    return model

# %%
wheat_model = wheat(IMG_SIZE)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 299, 299, 3)       0
#  a)
#
#  tf.nn.bias_add (TFOpLambda  (None, 299, 299, 3)       0
#  )
#
#  tf.math.truediv_1 (TFOpLam  (None, 299, 299, 3)       0
#  bda)
#
#  densenet121 (Functional)    (None, 9, 9, 1024)        7037504
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 7)                 7175
#
# =================================================================
# Total params: 7044679 (26.87 MB)
# Trainable params: 3058759 (11.67 MB)
# Non-trainable params: 3985920 (15.21 MB)
# _________________________________________________________________

# %%
base_learning_rate = 0.001
wheat_model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
model_filepath="/content/drive/MyDrive/wheatdensenet-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(
    filepath = model_filepath ,
    monitor ='val_accuracy',
    mode = 'max' ,
    save_best_only =True ,
    verbose = 1
)

# %%
history = wheat_model.fit(train_dataset, verbose = 2, epochs = 50, class_weight= class_weight,
                               validation_data = valid_dataset, use_multiprocessing = True, callbacks=[checkpoint])
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.97348, saving model to /content/drive/MyDrive/wheatdensenet-01-0.9735.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 19/19 - 146s - loss: 0.6631 - accuracy: 0.4918 - val_loss: 0.4469 - val_accuracy: 0.9735 - 146s/epoch - 8s/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.97348 to 0.97727, saving model to /content/drive/MyDrive/wheatdensenet-02-0.9773.hdf5
# 19/19 - 26s - loss: 0.1358 - accuracy: 0.9333 - val_loss: 0.0736 - val_accuracy: 0.9773 - 26s/epoch - 1s/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.97727 to 0.98864, saving model to /content/drive/MyDrive/wheatdensenet-03-0.9886.hdf5
# 19/19 - 26s - loss: 0.0102 - accuracy: 0.9937 - val_loss: 0.0192 - val_accuracy: 0.9886 - 26s/epoch - 1s/step
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.98864 to 0.99242, saving model to /content/drive/MyDrive/wheatdensenet-04-0.9924.hdf5
# 19/19 - 28s - loss: 0.0041 - accuracy: 0.9962 - val_loss: 0.0132 - val_accuracy: 0.9924 - 28s/epoch - 1s/step
# Epoch 5/50
#
# Epoch 5: val_accuracy did not improve from 0.99242
# 19/19 - 27s - loss: 0.0018 - accuracy: 0.9983 - val_loss: 0.0137 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 6/50
#
# Epoch 6: val_accuracy did not improve from 0.99242
# 19/19 - 25s - loss: 0.0018 - accuracy: 0.9983 - val_loss: 0.0244 - val_accuracy: 0.9886 - 25s/epoch - 1s/step
# Epoch 7/50
#
# Epoch 7: val_accuracy did not improve from 0.99242
# 19/19 - 28s - loss: 2.4646e-04 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9924 - 28s/epoch - 1s/step
# Epoch 8/50
#
# Epoch 8: val_accuracy improved from 0.99242 to 0.99621, saving model to /content/drive/MyDrive/wheatdensenet-08-0.9962.hdf5
# 19/19 - 26s - loss: 7.5356e-05 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9962 - 26s/epoch - 1s/step
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 3.9393e-05 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 1.2748e-05 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 1.8112e-05 - accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 7.8177e-06 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 5.5163e-06 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 0.99621
# 19/19 - 24s - loss: 4.0985e-06 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9924 - 24s/epoch - 1s/step
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.99621
# 19/19 - 24s - loss: 3.7322e-06 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9924 - 24s/epoch - 1s/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.99621
# 19/19 - 24s - loss: 1.4682e-06 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9924 - 24s/epoch - 1s/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.99621
# 19/19 - 25s - loss: 2.0503e-06 - accuracy: 1.0000 - val_loss: 0.0446 - val_accuracy: 0.9924 - 25s/epoch - 1s/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.99621
# 19/19 - 25s - loss: 1.0748e-06 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 0.9924 - 25s/epoch - 1s/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 1.0482e-06 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.99621
# 19/19 - 24s - loss: 1.9814e-06 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 0.9924 - 24s/epoch - 1s/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.99621
# 19/19 - 24s - loss: 1.3153e-05 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9924 - 24s/epoch - 1s/step
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 8.9263e-07 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 4.3804e-06 - accuracy: 1.0000 - val_loss: 0.0477 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.99621
# 19/19 - 25s - loss: 4.5609e-07 - accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 0.9924 - 25s/epoch - 1s/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.99621
# 19/19 - 28s - loss: 2.9944e-07 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9924 - 28s/epoch - 1s/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 2.8835e-07 - accuracy: 1.0000 - val_loss: 0.0505 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.99621
# 19/19 - 25s - loss: 2.6246e-07 - accuracy: 1.0000 - val_loss: 0.0518 - val_accuracy: 0.9924 - 25s/epoch - 1s/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 8.2252e-07 - accuracy: 1.0000 - val_loss: 0.0527 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.99621
# 19/19 - 24s - loss: 8.4656e-07 - accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 0.9924 - 24s/epoch - 1s/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.99621
# 19/19 - 24s - loss: 1.9971e-07 - accuracy: 1.0000 - val_loss: 0.0517 - val_accuracy: 0.9924 - 24s/epoch - 1s/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.99621
# 19/19 - 25s - loss: 1.5469e-07 - accuracy: 1.0000 - val_loss: 0.0529 - val_accuracy: 0.9924 - 25s/epoch - 1s/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 0.99621
# 19/19 - 30s - loss: 4.7197e-07 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 0.9924 - 30s/epoch - 2s/step
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.99621
# 19/19 - 28s - loss: 1.7768e-07 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 0.9924 - 28s/epoch - 1s/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 9.8324e-07 - accuracy: 1.0000 - val_loss: 0.0552 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 5.9940e-07 - accuracy: 1.0000 - val_loss: 0.0588 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 7.5318e-08 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 2.1238e-07 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.99621
# 19/19 - 28s - loss: 1.6237e-07 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9924 - 28s/epoch - 1s/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 8.5749e-08 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.99621
# 19/19 - 24s - loss: 2.3001e-07 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9924 - 24s/epoch - 1s/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 5.4098e-08 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 6.0029e-08 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 3.1182e-07 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 1.4952e-08 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 1.9296e-08 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9924 - 26s/epoch - 1s/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.99621
# 19/19 - 25s - loss: 1.5758e-07 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9924 - 25s/epoch - 1s/step
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.99621
# 19/19 - 27s - loss: 1.2217e-07 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9924 - 27s/epoch - 1s/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.99621
# 19/19 - 29s - loss: 4.2802e-08 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9924 - 29s/epoch - 2s/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.99621
# 19/19 - 25s - loss: 1.8979e-08 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9924 - 25s/epoch - 1s/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.99621
# 19/19 - 26s - loss: 1.8562e-07 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9924 - 26s/epoch - 1s/step

# %%
wheat_model.evaluate(test_dataset, verbose = 1)
# Out:
# 3/3 [==============================] - 3s 385ms/step - loss: 0.0215 - accuracy: 0.9966
# [0.021483156830072403, 0.9965870380401611]

# %%
plt.figure(figsize=(20, 15))
for images, labels in test_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = wheat_model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = wheat_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 9s 109ms/step
# 4/4 [==============================] - 1s 147ms/step
# 2/2 [==============================] - 5s 3s/step
# ROC AUC for Wheat___Brown_Rust: 0.9975
# ROC AUC for Wheat___Healthy: 1.0000
# ROC AUC for Wheat___Yellow_Rust: 0.9946
#                      precision    recall  f1-score   support
#
#  Wheat___Brown_Rust       0.99      1.00      0.99        90
#     Wheat___Healthy       1.00      1.00      1.00       111
# Wheat___Yellow_Rust       1.00      0.99      0.99        92
#
#            accuracy                           1.00       293
#           macro avg       1.00      1.00      1.00       293
#        weighted avg       1.00      1.00      1.00       293

# %%
from sklearn.metrics import classification_report, confusion_matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix (Inceptionv3)')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = wheat_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves
plt.figure(figsize=(10, 8))

for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f}) for {class_names[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification (Inceptionv3)')
plt.legend(loc='lower right')
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 1s 169ms/step
# 4/4 [==============================] - 1s 151ms/step
# 2/2 [==============================] - 0s 144ms/step
# ROC AUC for Wheat___Brown_Rust: 0.9975
# ROC AUC for Wheat___Healthy: 1.0000
# ROC AUC for Wheat___Yellow_Rust: 0.9946
#                      precision    recall  f1-score   support
#
#  Wheat___Brown_Rust       0.99      1.00      0.99        90
#     Wheat___Healthy       1.00      1.00      1.00       111
# Wheat___Yellow_Rust       1.00      0.99      0.99        92
#
#            accuracy                           1.00       293
#           macro avg       1.00      1.00      1.00       293
#        weighted avg       1.00      1.00      1.00       293
