# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
import glob as gb

from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
IMG_SIZE = (299, 299) # resolution
directory = "/content/drive/MyDrive/Potato"
BATCH_SIZE = 128
# train_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.2,
#                                              subset='training',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)
# validation_dataset1 = image_dataset_from_directory(directory,
#                                              shuffle=True,
#                                              labels='inferred',
#                                              batch_size=BATCH_SIZE,
#                                              image_size=IMG_SIZE,
#                                              validation_split=0.1,
#                                              subset='validation',
#                                              color_mode='rgb',
#                                              seed=42)

# %%
import os
import shutil

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Potato'
destination_folder = '/content/drive/MyDrive/potatotest'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the first specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Get the first specified percentage of files
            files_to_move = files_in_subfolder[:num_files_to_move]

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Potato'
destination_folder = '/content/drive/MyDrive/potatovalid'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 0.1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os
import shutil
import random

# Set the path to your source and destination folders
source_folder = '/content/drive/MyDrive/Potato'
destination_folder = '/content/drive/MyDrive/potatotrain'

# Set the desired percentage of images to move (e.g., 10%)
move_percentage = 1

# Function to move the specified percentage of files from source to destination folder
def move_files(source_folder, destination_folder, move_percentage):
    # Iterate through each subfolder in the source directory
    for subfolder in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Get the list of files in the subfolder
            files_in_subfolder = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

            # Calculate the number of files to move based on the percentage
            num_files_to_move = max(1, int(move_percentage * len(files_in_subfolder)))

            # Ensure the number of files to move is not greater than the available files
            num_files_to_move = min(num_files_to_move, len(files_in_subfolder))

            # Get the specified percentage of files randomly
            files_to_move = random.sample(files_in_subfolder, num_files_to_move)

            # Create subdirectories in the destination folder
            destination_subfolder = os.path.join(destination_folder, subfolder)
            os.makedirs(destination_subfolder, exist_ok=True)

            # Move selected files to the destination subfolder
            for file in files_to_move:
                source_path = os.path.join(subfolder_path, file)
                destination_path = os.path.join(destination_subfolder, file)

                try:
                    shutil.move(source_path, destination_path)
                    print(f"Successfully moved {file} from {subfolder_path} to {destination_subfolder}")
                except Exception as e:
                    print(f"Error moving {file} from {subfolder_path} to {destination_subfolder}: {e}")

# Move files to the destination folder
move_files(source_folder, destination_folder, move_percentage)

# %%
import os

# Set the path to the source folder
source_folder = '/content/drive/MyDrive/Potato'

# Function to count classes and total images
def count_classes_and_images(folder_path):
    classes = os.listdir(folder_path)
    total_classes = len(classes)
    total_images = 0

    for class_name in classes:
        class_path = os.path.join(folder_path, class_name)
        if os.path.isdir(class_path):
            images_in_class = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])
            total_images += images_in_class
            print(f"Class: {class_name}, Images: {images_in_class}")

    print(f"Total Classes: {total_classes}, Total Images: {total_images}")

# Count classes and total images in the source folder
count_classes_and_images(source_folder)
# Out:
# Class: Potato___Late_Blight, Images: 0
# Class: Potato___Early_Blight, Images: 0
# Class: Potato___Healthy, Images: 0
# Total Classes: 3, Total Images: 0

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

IMG_SIZE = (299, 299)  # resolution
BATCH_SIZE = 128

# Define the directories for training, testing, and validation
train_directory = '/content/drive/MyDrive/potatotrain'
test_directory = '/content/drive/MyDrive/potatotest'
valid_directory = '/content/drive/MyDrive/potatovalid'

# Create TensorFlow datasets
train_dataset = image_dataset_from_directory(
    train_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

test_dataset = image_dataset_from_directory(
    test_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

valid_dataset = image_dataset_from_directory(
    valid_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

# Optional: You can also specify the class names if you have a specific order for your classes
class_names = train_dataset.class_names

# Print class names
print("Class Names:", class_names)
# Out:
# Found 1753 files belonging to 3 classes.
# Found 216 files belonging to 3 classes.
# Found 193 files belonging to 3 classes.
# Class Names: ['Potato___Early_Blight', 'Potato___Healthy', 'Potato___Late_Blight']

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Potato___Early_Blight', 'Potato___Healthy', 'Potato___Late_Blight']

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(train_directory):
    files = gb.glob(pathname=str(train_directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
plt.figure(figsize=(9,5))
sns.barplot(x=['Potato___Early_Blight', 'Potato___Healthy', 'Potato___Late_Blight'], y=Data_imbalance, palette="crest")
plt.show()

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import glob as gb

sns.set_theme(style="whitegrid")

# Assuming you already have Data_imbalance calculated
# If not, you should calculate it before using it in this code

# Print the dataset class-wise count
for folder, count in zip(['Potato___Early_Blight', 'Potato___Healthy', 'Potato___Late_Blight'], Data_imbalance):
    print(f"Class '{folder}': {count} samples")

# Create the bar plot
plt.figure(figsize=(13,7))
sns.barplot(x=['Potato___Early_Blight', 'Potato___Healthy', 'Potato___Late_Blight'], y=Data_imbalance, palette="rocket")
plt.show()
# Out:
# Class 'Potato___Early_Blight': 810 samples
# Class 'Potato___Healthy': 819 samples
# Class 'Potato___Late_Blight': 124 samples

# %%
total = 0
for i in range(0,len(Data_imbalance)) :
    total +=Data_imbalance[i]

weight_for_0 = (1 / Data_imbalance[0]) * (total / 7.0)
weight_for_1 = (1 / Data_imbalance[1]) * (total / 7.0)
weight_for_2 = (1 / Data_imbalance[2]) * (total / 7.0)
# weight_for_3 = (1 / Data_imbalance[3]) * (total / 7.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2}    # , 3: weight_for_3

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
# print('Weight for class 3: {:.2f}'.format(weight_for_3))
# Out:
# Weight for class 0: 0.31
# Weight for class 1: 0.31
# Weight for class 2: 2.02

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
augmented_count = 0

for image, _ in train_dataset:
    augmented_images = data_augmentation(image)
    augmented_count += augmented_images.shape[0]  # Count the number of augmented images

original_count = len(train_dataset) * BATCH_SIZE  # Total number of original images
total_count = original_count + augmented_count    # Total number of images after augmentation

increase_percentage = ((total_count - original_count) / original_count) * 100

print(f"Original image count: {original_count}")
print(f"Augmented image count: {augmented_count}")
print(f"Total image count after augmentation: {total_count}")
print(f"Increase in image count: {increase_percentage:.2f}%")
# Out:
# Original image count: 1792
# Augmented image count: 1753
# Total image count after augmentation: 3545
# Increase in image count: 97.82%

# %%
IMG_SHAPE = IMG_SIZE +(3,)
base_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE, include_top= False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
type(base_model)
preprocess_input = tf.keras.applications.resnet.preprocess_input

# %%
nb_layers = len(base_model.layers)
print("Numbers of Layers =" , nb_layers)
print(base_model.layers[nb_layers - 2].name)  # pre- Last name
print(base_model.layers[nb_layers - 1].name)
# Out:
# Numbers of Layers = 175
# conv5_block3_add
# conv5_block3_out

# %%
# iterate over first batch (32 image) in trainset
image_batch, label_batch = next(iter(train_dataset))  # 32 image arrays
feature_batch = base_model(image_batch)  # run the model on those 32 image (base model with its 1000 causes classification)
print(feature_batch.shape)  # 32 for number of images in this batch and 1000 for classes
# Out:
# (128, 10, 10, 2048)

# %%
def potato(image_shape=IMG_SIZE):
    ''' Define a tf.keras model for multi-class classification out of the InceptionV3 model '''
    image_shape = image_shape + (3,)

    resnet_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE, include_top= False,weights='imagenet')
    resnet_model.trainable = True
    for layer in resnet_model.layers[0 : 291]:
        layer.trainable = False

    inputs = tf.keras.Input(image_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(inputs)
    x = resnet_model(x , training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    prediction_layer = tf.keras.layers.Dense(7 ,activation = "softmax")
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)
    model.summary()
    return model

# %%
potato_model = potato(IMG_SIZE)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  tf.__operators__.getitem (  (None, 299, 299, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 299, 299, 3)       0
#  )
#
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 7)                 14343
#
# =================================================================
# Total params: 23602055 (90.03 MB)
# Trainable params: 14343 (56.03 KB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
base_learning_rate = 0.001
potato_model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
model_filepath="/content/drive/MyDrive/potatoresnet-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(
    filepath = model_filepath ,
    monitor ='val_accuracy',
    mode = 'max' ,
    save_best_only =True ,
    verbose = 1
)

# %%
history = potato_model.fit(train_dataset, verbose = 2, epochs = 50, class_weight= class_weight,
                               validation_data = valid_dataset, use_multiprocessing = True, callbacks=[checkpoint])
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.50777, saving model to /content/drive/MyDrive/potatoresnet-01-0.5078.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 - 110s - loss: 0.8452 - accuracy: 0.4387 - val_loss: 0.9057 - val_accuracy: 0.5078 - 110s/epoch - 8s/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.50777 to 0.84456, saving model to /content/drive/MyDrive/potatoresnet-02-0.8446.hdf5
# 14/14 - 15s - loss: 0.3153 - accuracy: 0.6880 - val_loss: 0.5096 - val_accuracy: 0.8446 - 15s/epoch - 1s/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.84456 to 0.88601, saving model to /content/drive/MyDrive/potatoresnet-03-0.8860.hdf5
# 14/14 - 16s - loss: 0.1932 - accuracy: 0.8511 - val_loss: 0.3316 - val_accuracy: 0.8860 - 16s/epoch - 1s/step
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.88601 to 0.91192, saving model to /content/drive/MyDrive/potatoresnet-04-0.9119.hdf5
# 14/14 - 16s - loss: 0.1478 - accuracy: 0.8819 - val_loss: 0.2555 - val_accuracy: 0.9119 - 16s/epoch - 1s/step
# Epoch 5/50
#
# Epoch 5: val_accuracy did not improve from 0.91192
# 14/14 - 15s - loss: 0.1161 - accuracy: 0.9019 - val_loss: 0.2024 - val_accuracy: 0.9119 - 15s/epoch - 1s/step
# Epoch 6/50
#
# Epoch 6: val_accuracy did not improve from 0.91192
# 14/14 - 15s - loss: 0.0981 - accuracy: 0.9116 - val_loss: 0.1818 - val_accuracy: 0.9119 - 15s/epoch - 1s/step
# Epoch 7/50
#
# Epoch 7: val_accuracy improved from 0.91192 to 0.92746, saving model to /content/drive/MyDrive/potatoresnet-07-0.9275.hdf5
# 14/14 - 18s - loss: 0.0851 - accuracy: 0.9241 - val_loss: 0.1466 - val_accuracy: 0.9275 - 18s/epoch - 1s/step
# Epoch 8/50
#
# Epoch 8: val_accuracy improved from 0.92746 to 0.93264, saving model to /content/drive/MyDrive/potatoresnet-08-0.9326.hdf5
# 14/14 - 17s - loss: 0.0769 - accuracy: 0.9276 - val_loss: 0.1330 - val_accuracy: 0.9326 - 17s/epoch - 1s/step
# Epoch 9/50
#
# Epoch 9: val_accuracy improved from 0.93264 to 0.94819, saving model to /content/drive/MyDrive/potatoresnet-09-0.9482.hdf5
# 14/14 - 16s - loss: 0.0648 - accuracy: 0.9469 - val_loss: 0.1205 - val_accuracy: 0.9482 - 16s/epoch - 1s/step
# Epoch 10/50
#
# Epoch 10: val_accuracy improved from 0.94819 to 0.95855, saving model to /content/drive/MyDrive/potatoresnet-10-0.9585.hdf5
# 14/14 - 16s - loss: 0.0597 - accuracy: 0.9509 - val_loss: 0.1040 - val_accuracy: 0.9585 - 16s/epoch - 1s/step
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.95855
# 14/14 - 16s - loss: 0.0554 - accuracy: 0.9578 - val_loss: 0.1079 - val_accuracy: 0.9534 - 16s/epoch - 1s/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.95855
# 14/14 - 16s - loss: 0.0487 - accuracy: 0.9629 - val_loss: 0.0965 - val_accuracy: 0.9585 - 16s/epoch - 1s/step
# Epoch 13/50
#
# Epoch 13: val_accuracy improved from 0.95855 to 0.96373, saving model to /content/drive/MyDrive/potatoresnet-13-0.9637.hdf5
# 14/14 - 16s - loss: 0.0468 - accuracy: 0.9635 - val_loss: 0.0836 - val_accuracy: 0.9637 - 16s/epoch - 1s/step
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 0.96373
# 14/14 - 16s - loss: 0.0428 - accuracy: 0.9686 - val_loss: 0.0888 - val_accuracy: 0.9585 - 16s/epoch - 1s/step
# Epoch 15/50
#
# Epoch 15: val_accuracy improved from 0.96373 to 0.97409, saving model to /content/drive/MyDrive/potatoresnet-15-0.9741.hdf5
# 14/14 - 16s - loss: 0.0416 - accuracy: 0.9692 - val_loss: 0.0715 - val_accuracy: 0.9741 - 16s/epoch - 1s/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.97409
# 14/14 - 15s - loss: 0.0389 - accuracy: 0.9720 - val_loss: 0.0731 - val_accuracy: 0.9689 - 15s/epoch - 1s/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.97409
# 14/14 - 15s - loss: 0.0377 - accuracy: 0.9663 - val_loss: 0.0730 - val_accuracy: 0.9689 - 15s/epoch - 1s/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.97409
# 14/14 - 16s - loss: 0.0344 - accuracy: 0.9738 - val_loss: 0.0666 - val_accuracy: 0.9741 - 16s/epoch - 1s/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.97409
# 14/14 - 18s - loss: 0.0334 - accuracy: 0.9738 - val_loss: 0.0622 - val_accuracy: 0.9741 - 18s/epoch - 1s/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.97409
# 14/14 - 16s - loss: 0.0319 - accuracy: 0.9760 - val_loss: 0.0648 - val_accuracy: 0.9741 - 16s/epoch - 1s/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.97409
# 14/14 - 15s - loss: 0.0280 - accuracy: 0.9823 - val_loss: 0.0600 - val_accuracy: 0.9741 - 15s/epoch - 1s/step
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.97409
# 14/14 - 17s - loss: 0.0306 - accuracy: 0.9760 - val_loss: 0.0542 - val_accuracy: 0.9741 - 17s/epoch - 1s/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.97409
# 14/14 - 15s - loss: 0.0281 - accuracy: 0.9817 - val_loss: 0.0550 - val_accuracy: 0.9741 - 15s/epoch - 1s/step
# Epoch 24/50
#
# Epoch 24: val_accuracy improved from 0.97409 to 0.97927, saving model to /content/drive/MyDrive/potatoresnet-24-0.9793.hdf5
# 14/14 - 16s - loss: 0.0254 - accuracy: 0.9806 - val_loss: 0.0516 - val_accuracy: 0.9793 - 16s/epoch - 1s/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.97927
# 14/14 - 15s - loss: 0.0276 - accuracy: 0.9835 - val_loss: 0.0563 - val_accuracy: 0.9741 - 15s/epoch - 1s/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.97927
# 14/14 - 15s - loss: 0.0235 - accuracy: 0.9846 - val_loss: 0.0485 - val_accuracy: 0.9793 - 15s/epoch - 1s/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.97927
# 14/14 - 17s - loss: 0.0231 - accuracy: 0.9863 - val_loss: 0.0468 - val_accuracy: 0.9793 - 17s/epoch - 1s/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.97927
# 14/14 - 16s - loss: 0.0243 - accuracy: 0.9840 - val_loss: 0.0476 - val_accuracy: 0.9793 - 16s/epoch - 1s/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.97927
# 14/14 - 15s - loss: 0.0224 - accuracy: 0.9817 - val_loss: 0.0473 - val_accuracy: 0.9793 - 15s/epoch - 1s/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.97927
# 14/14 - 17s - loss: 0.0206 - accuracy: 0.9863 - val_loss: 0.0435 - val_accuracy: 0.9793 - 17s/epoch - 1s/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.97927
# 14/14 - 16s - loss: 0.0205 - accuracy: 0.9852 - val_loss: 0.0434 - val_accuracy: 0.9793 - 16s/epoch - 1s/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 0.97927
# 14/14 - 15s - loss: 0.0208 - accuracy: 0.9880 - val_loss: 0.0439 - val_accuracy: 0.9793 - 15s/epoch - 1s/step
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.97927
# 14/14 - 17s - loss: 0.0207 - accuracy: 0.9869 - val_loss: 0.0436 - val_accuracy: 0.9793 - 17s/epoch - 1s/step
# Epoch 34/50
#
# Epoch 34: val_accuracy improved from 0.97927 to 0.98446, saving model to /content/drive/MyDrive/potatoresnet-34-0.9845.hdf5
# 14/14 - 16s - loss: 0.0170 - accuracy: 0.9920 - val_loss: 0.0400 - val_accuracy: 0.9845 - 16s/epoch - 1s/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.98446
# 14/14 - 15s - loss: 0.0190 - accuracy: 0.9880 - val_loss: 0.0444 - val_accuracy: 0.9793 - 15s/epoch - 1s/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.98446
# 14/14 - 17s - loss: 0.0188 - accuracy: 0.9857 - val_loss: 0.0422 - val_accuracy: 0.9793 - 17s/epoch - 1s/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.98446
# 14/14 - 15s - loss: 0.0171 - accuracy: 0.9909 - val_loss: 0.0383 - val_accuracy: 0.9793 - 15s/epoch - 1s/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.98446
# 14/14 - 15s - loss: 0.0152 - accuracy: 0.9903 - val_loss: 0.0393 - val_accuracy: 0.9793 - 15s/epoch - 1s/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.98446
# 14/14 - 16s - loss: 0.0153 - accuracy: 0.9914 - val_loss: 0.0385 - val_accuracy: 0.9793 - 16s/epoch - 1s/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.98446
# 14/14 - 17s - loss: 0.0156 - accuracy: 0.9914 - val_loss: 0.0388 - val_accuracy: 0.9793 - 17s/epoch - 1s/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.98446
# 14/14 - 16s - loss: 0.0164 - accuracy: 0.9886 - val_loss: 0.0369 - val_accuracy: 0.9793 - 16s/epoch - 1s/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.98446
# 14/14 - 16s - loss: 0.0149 - accuracy: 0.9920 - val_loss: 0.0369 - val_accuracy: 0.9845 - 16s/epoch - 1s/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.98446
# 14/14 - 17s - loss: 0.0156 - accuracy: 0.9897 - val_loss: 0.0355 - val_accuracy: 0.9845 - 17s/epoch - 1s/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.98446
# 14/14 - 17s - loss: 0.0141 - accuracy: 0.9897 - val_loss: 0.0350 - val_accuracy: 0.9845 - 17s/epoch - 1s/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.98446
# 14/14 - 17s - loss: 0.0128 - accuracy: 0.9937 - val_loss: 0.0348 - val_accuracy: 0.9845 - 17s/epoch - 1s/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.98446
# 14/14 - 16s - loss: 0.0139 - accuracy: 0.9914 - val_loss: 0.0355 - val_accuracy: 0.9845 - 16s/epoch - 1s/step
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.98446
# 14/14 - 16s - loss: 0.0126 - accuracy: 0.9909 - val_loss: 0.0341 - val_accuracy: 0.9845 - 16s/epoch - 1s/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.98446
# 14/14 - 15s - loss: 0.0123 - accuracy: 0.9943 - val_loss: 0.0326 - val_accuracy: 0.9845 - 15s/epoch - 1s/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.98446
# 14/14 - 17s - loss: 0.0124 - accuracy: 0.9932 - val_loss: 0.0336 - val_accuracy: 0.9845 - 17s/epoch - 1s/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.98446
# 14/14 - 15s - loss: 0.0110 - accuracy: 0.9943 - val_loss: 0.0320 - val_accuracy: 0.9845 - 15s/epoch - 1s/step

# %%
potato_model.evaluate(test_dataset, verbose = 1)
# Out:
# 2/2 [==============================] - 89s 9s/step - loss: 0.0565 - accuracy: 0.9769
# [0.056465961039066315, 0.9768518805503845]

# %%
plt.figure(figsize=(20, 15))
for images, labels in test_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = potato_model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = potato_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 5s 119ms/step
# 3/3 [==============================] - 4s 2s/step
# ROC AUC for Potato___Early_Blight: 0.9950
# ROC AUC for Potato___Healthy: 0.8667
# ROC AUC for Potato___Late_Blight: 0.9784
#                        precision    recall  f1-score   support
#
# Potato___Early_Blight       1.00      0.99      1.00       101
#      Potato___Healthy       1.00      0.73      0.85        15
#  Potato___Late_Blight       0.95      1.00      0.98       100
#
#              accuracy                           0.98       216
#             macro avg       0.98      0.91      0.94       216
#          weighted avg       0.98      0.98      0.98       216

# %%
from sklearn.metrics import classification_report, confusion_matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix (Inceptionv3)')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = potato_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves
plt.figure(figsize=(10, 8))

for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f}) for {class_names[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification (Inceptionv3)')
plt.legend(loc='lower right')
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 1s 170ms/step
# 3/3 [==============================] - 0s 159ms/step
# ROC AUC for Potato___Early_Blight: 0.9950
# ROC AUC for Potato___Healthy: 0.8667
# ROC AUC for Potato___Late_Blight: 0.9784
#                        precision    recall  f1-score   support
#
# Potato___Early_Blight       1.00      0.99      1.00       101
#      Potato___Healthy       1.00      0.73      0.85        15
#  Potato___Late_Blight       0.95      1.00      0.98       100
#
#              accuracy                           0.98       216
#             macro avg       0.98      0.91      0.94       216
#          weighted avg       0.98      0.98      0.98       216
